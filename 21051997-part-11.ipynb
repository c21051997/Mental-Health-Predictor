# %% [markdown]
# ### **Reminder:**
#
# ### For each notebook, you should submit your notebook with all the cells executed, from start to finish, in a fresh run (i.e., first cell number should be [1], second [2], etc.). You can achieve this by selecting Kernel -> Restart and run all. At the end of the run, your notebook should have populated a database in the university server which you will have created exclusively for this coursework.
#
# ### **Any deviation from the submission instructions above will result in a mark of zero for the assessment or question part.**
#
# # Part 1: NOTEBOOK: DATABASE CREATION AND QUERYING [30 marks]

# %%
import pymysql
import pandas as pd

# %%
connection = pymysql.connect(
    host='csmysql.cs.cf.ac.uk',
    user='c21051997',
    password='14Swissvalley!',
    database='c21051997_cmt655_coursework_db',
    charset='utf8mb4')

# %% [markdown]
# PART A: DATA MODELING [10 marks]
#
# 1) Python logic for reading in the data and handling missing values. Use of Pandas is recommended. Note: you can reuse code from Part 2 questions 1 and 3 for this question. [1 mark]

# %%
# your code here

# Read the CSV file containg the data, store into a "DataFrame"
df = pd.read_csv("art.csv")

# Replace any missing values in the DataFrame with "\\N"
df.fillna("\\N", inplace=True)

# Save the cleaned DataFrame into a new CSV file called cleaned_paintings, not including the index column
df.to_csv("cleaned_paintings.csv", index=False)

# %% [markdown]
# 2) SQL code for creating tables. [4 marks]

# %%
# Create three tables - Artists, Museums, Paintings
try:
    
    # Use the cursor to interact with the database
    with connection.cursor() as cur:

        # Drop the tables if they already exist so they can be recreated
        cur.execute("DROP TABLE IF EXISTS paintings;")
        cur.execute("DROP TABLE IF EXISTS museums;")
        cur.execute("DROP TABLE IF EXISTS artists;")

        # Create 'artists' table to store artist information
        cur.execute("""
            CREATE TABLE IF NOT EXISTS artists (
                artist_id INT AUTO_INCREMENT PRIMARY KEY, # Generate unique artist IDs
                artist_name VARCHAR(255) NOT NULL UNIQUE, # Artist name assumed to be unique
                artist_nationality VARCHAR(225),
                artist_style VARCHAR(225),
                artist_birth SMALLINT,
                artist_death SMALLINT
            ) CHARACTER SET utf8mb4 COLLATE utf8mb4_general_ci; # Use utf8mb4 charset for foreign character support
        """)

        # Create 'museums' table to store museum information
        cur.execute("""
            CREATE TABLE IF NOT EXISTS museums (
                museum_id INT AUTO_INCREMENT PRIMARY KEY,
                museum_name VARCHAR(255) NOT NULL UNIQUE,
                museum_city VARCHAR(225),
                museum_country VARCHAR(225)
            ) CHARACTER SET utf8mb4 COLLATE utf8mb4_general_ci;
        """)

        # Create 'paintings' table to store paintings information
        cur.execute("""
            CREATE TABLE IF NOT EXISTS paintings (
                painting_id INT AUTO_INCREMENT PRIMARY KEY,
                painting_name VARCHAR(255) NOT NULL UNIQUE,
                painting_style VARCHAR(225),
                painting_subject VARCHAR(225),
                artist_id INT, # Foreign keys referencing the artist and museum tables
                museum_id INT,
                FOREIGN KEY (artist_id) REFERENCES artists(artist_id) ON DELETE SET NULL, # Set the ids to null if the record is deleted
                FOREIGN KEY (museum_id) REFERENCES museums(museum_id) ON DELETE SET NULL
            ) CHARACTER SET utf8mb4 COLLATE utf8mb4_general_ci;
        """)

        # Commit the changes to the database to save the created tables
        connection.commit()

finally:
    # Close the connection
    # connection.close()
    pass

# %% [markdown]
# 3) SQL code for populating tables. [5 marks]

# %%
# your code here

# Extract all columns from the DataFrame and remove dplicate rows
artists_data = df[['artist', 'artist_nationality', 'artist_style', 'artist_birth', 'artist_death']].drop_duplicates().values.tolist()
museums_data = df[['museum', 'museum_city', 'museum_country']].drop_duplicates().values.tolist()
paintings_data = df[['painting', 'painting_style', 'painting_subject', 'artist', 'museum']].drop_duplicates().values.tolist()

try:
    with connection.cursor() as cur:

        # Initialise dictionary to store the artist name as the key along with their id
        artist_ids = {}
        print("Inserting artists")

        # Loop through all artist data rows
        for artist in artists_data:
            try:

                # Check if the artist already exists in the artists table
                cur.execute("""
                    SELECT artist_id 
                    FROM artists 
                    WHERE artist_name = %(artist_name)s
                """, {"artist_name": artist[0]})

                # Fetch the results of the query
                check_duplicate = cur.fetchone()

                if check_duplicate: 
                    # If the artist does already exist, get their id
                    artist_id = check_duplicate[0]
                else:
                    # If the artist does not exist, insert a new artist
                    cur.execute("""
                        INSERT INTO artists (artist_name, artist_nationality, artist_style, artist_birth, artist_death)
                        VALUES (%(artist_name)s, %(artist_nationality)s, %(artist_style)s, %(artist_birth)s, %(artist_death)s)
                    """, {"artist_name": artist[0], "artist_nationality": artist[1], "artist_style": artist[2], 
                          "artist_birth": artist[3], "artist_death": artist[4]})
                    
                    # Get the artist id of the newly inserted artist
                    artist_id = cur.lastrowid

                # Add the artist name and ID in the directionary
                artist_ids[artist[0]] = artist_id 

            except Exception as e:
                # Prit an error message if there is an issue inserting the artist
                print(f"Failed to insert: {artist} — Error: {e}")
                raise # Stop the execution
        
        # Repeat the same process for the museums data
        museum_ids = {}
        print("Inserting museums")

        for museum in museums_data:
            try:
                cur.execute("""
                    SELECT museum_id 
                    FROM museums 
                    WHERE museum_name = %(museum_name)s
                """, {"museum_name": museum[0]}) #must have , to avoid potential errors, must be a tuple

                check_duplicate = cur.fetchone()

                if check_duplicate: 
                    museum_id = check_duplicate[0]

                else:
                    cur.execute("""
                        INSERT INTO museums (museum_name, museum_city, museum_country)
                        VALUES (%(museum_name)s, %(museum_city)s, %(museum_country)s)
                    """, {"museum_name": museum[0], "museum_city": museum[1], "museum_country": museum[2]})
                    
                    museum_id = cur.lastrowid

                museum_ids[museum[0]] = museum_id 
            
            except Exception as e:
                print(f"Failed to insert: {museum} — Error: {e}")
                raise
        
        # List to store the painting data, used with the "executemany" command
        painting_inserts = []
        print("Inserting paintings")

        # Loop through each painting data
        for painting in paintings_data:
            
            # Get the artist and museum id from the dictionaries
            artist_id = artist_ids[painting[3]]
            museum_id = museum_ids[painting[4]]

            # Append the data to the painting inserts list
            painting_inserts.append((painting[0], painting[1], painting[2], artist_id, museum_id))
        
        # Insert all paintings in a single query to optimize performance
        cur.executemany("""
            INSERT IGNORE INTO paintings (painting_name, painting_style, painting_subject, artist_id, museum_id)
            VALUES (%s, %s, %s, %s, %s)
        """, painting_inserts)

        #  Commit changes to the database
        connection.commit()
        
finally:
    pass

# 23 seconds to execute
# Out:
# Inserting artists
# Inserting museums
# Inserting paintings

# %% [markdown]
# PART B: QUERYING [20 marks]
#
# 1 - First 10 artists with longest life  [4 marks]
#
# Implement a query that returns the top 10 artist with longest life span based on their birth year and year of death for the whole dataset. You should calculate the life span of each artist and sort them in in descending order. Your query should return the results in 3 columns containing the names, the art styles and the nationality of the top 10 artists using aggr_scores..

# %%
# your code here
try:
    with connection.cursor() as cur:
        cur.execute(""" 
            SELECT artist_name, artist_nationality, artist_style FROM artists
            WHERE artist_birth IS NOT NULL AND artist_death IS NOT NULL
            ORDER BY (artist_death - artist_birth) DESC LIMIT 10;
        """)

        results = cur.fetchall()
        for row in results:
            print(row)
finally:
    pass
# Out:
# ('Sir George Clausen', 'English', 'Realist')
# ('Kees Van Dongen', 'Dutch', 'Fauvist')
# ('Titian', 'Italian', 'High Renaissance')
# ('Asher Brown Durand', 'American', 'Hudson River School')
# ('Katsushika Hokusai', 'Japanese', 'Ukiyo-e')
# ('Frank Weston Benson', 'American', 'Impressionist')
# ('Buonarroti Michelangelo', 'Italian', 'High Renaissance')
# ('Christian Rohlfs', 'German', 'Expressionist')
# ('Thomas Moran', 'American', 'Hudson River School')
# ('Thomas Sully', 'American', 'Portraitist')

# %% [markdown]
# 2 - Find all the artists with style “Baroque” [4 marks]
#
# Implement a query that returns all the names of all paintings and their artists with style “Baroque”.  Your query should return three columns: painting, artist, and painting_style.

# %%
# your code here
try:
    with connection.cursor() as cur:
        cur.execute(""" 
            SELECT paintings.painting_name, artists.artist_name, paintings.painting_style FROM paintings
            JOIN artists ON paintings.artist_id = artists.artist_id
            WHERE artists.artist_style = "Baroque";
        """)

        # Fetch all results returned by the query
        results = cur.fetchall()

        # Loop through the results and print the artists details
        for row in results:
            print(row)
finally:
    pass
# Out:
# ('Still Life with Flowers and a Watch', 'Abraham Mignon', 'Baroque')
# ("Still Life with Fruit and a Beaker on a Cock's Foot", 'Abraham Mignon', 'Baroque')
# ('Still Life with Fruit and a Goldfinch', 'Abraham Mignon', 'Baroque')
# ('Still Life with Fruit and Oysters', 'Abraham Mignon', 'Baroque')
# ('Still Life with Fruit, Oysters, and a Porcelain Bowl', 'Abraham Mignon', 'Baroque')
# ('The Overturned Bouquet', 'Abraham Mignon', 'Baroque')
# ('Arabian Horses at Pasture', 'Albrecht Adam', 'Baroque')
# ('Count Halm on His Basedow Estate', 'Albrecht Adam', 'Baroque')
# ('Horses at the Porch', 'Albrecht Adam', 'Baroque')
# ('Napoleon Before the Burning City of Smolensk', 'Albrecht Adam', 'Baroque')
# ('Peasants Resting in the Field', 'Albrecht Adam', 'Baroque')
# ('Portrait Oberleutnant Theodor Von Klein', 'Albrecht Adam', 'Baroque')
# ('The Rescue of Count Munnich', 'Albrecht Adam', 'Baroque')
# ('The Stable Yard', 'Albrecht Adam', 'Baroque')
# ('A Distant View of Dordrecht, with a Milkmaid and Four Cows', 'Aelbert Cuyp', 'Baroque')
# ('A Herdsman with Seven Cows by a River', 'Aelbert Cuyp', 'Baroque')
# ('A Landscape with Horseman, Herders and Cattle', 'Aelbert Cuyp', 'Baroque')
# ('A View of the Maas at Dordrecht', 'Aelbert Cuyp', 'Baroque')
# ('Cattle in a River', 'Aelbert Cuyp', 'Baroque')
# ('Cattle Near a River', 'Aelbert Cuyp', 'Baroque')
# ('Cattle Near the Maas, with Dordrecht in the Distance', 'Aelbert Cuyp', 'Baroque')
# ('Cattle with Horseman and Peasants', 'Aelbert Cuyp', 'Baroque')
# ('Children and a Cow', 'Aelbert Cuyp', 'Baroque')
# ('Lady and Gentleman on Horseback', 'Aelbert Cuyp', 'Baroque')
# ('Landscape with Cattle', 'Aelbert Cuyp', 'Baroque')
# ('Landscape with Cows and Young Herdsman', 'Aelbert Cuyp', 'Baroque')
# ('Landscape with Herdsman and Cattle', 'Aelbert Cuyp', 'Baroque')
# ('Mountainous Landscape with the Ruins of a Castle', 'Aelbert Cuyp', 'Baroque')
# ('Piping Shepherds', 'Aelbert Cuyp', 'Baroque')
# ('River Landscape with Cows', 'Aelbert Cuyp', 'Baroque')
# ('River Landscape with Riders', 'Aelbert Cuyp', 'Baroque')
# ('River Scene', 'Aelbert Cuyp', 'Baroque')
# ('Rooster and Hens', 'Aelbert Cuyp', 'Baroque')
# ('Senior Merchant', 'Aelbert Cuyp', 'Baroque')
# ('Starting for the Hunt', 'Aelbert Cuyp', 'Baroque')
# ('The Flight into Egypt', 'Aelbert Cuyp', 'Baroque')
# ('The Maas at Dordrecht', 'Aelbert Cuyp', 'Baroque')
# ('The Passage Boat', 'Aelbert Cuyp', 'Baroque')
# ('Travelers in Hilly Countryside', 'Aelbert Cuyp', 'Baroque')
# ('View of Dordrecht at Sunset', 'Aelbert Cuyp', 'Baroque')
# ('View of the Maas near Dordrecht', 'Aelbert Cuyp', 'Baroque')
# ('Young Herdsmen with Cows', 'Aelbert Cuyp', 'Baroque')
# ('Bouquet of Flowers in a Glass Vase', 'Ambrosius Bosschaert', 'Rococo')
# ('Bouquet of Flowers on a Ledge', 'Ambrosius Bosschaert', 'Rococo')
# ('Flower Still Life', 'Ambrosius Bosschaert', 'Rococo')
# ('Flowers in a Berkemeier Glass on a Stone Ledge', 'Ambrosius Bosschaert', 'Rococo')
# ('Flowers in a Glass Vase', 'Ambrosius Bosschaert', 'Rococo')
# ('Fruit in a Wicker Basket with a Lizard and a Red Admiral Butterfly on a Stone Ledge', 'Ambrosius Bosschaert', 'Rococo')
# ('Fruit Still Life with Shells', 'Ambrosius Bosschaert', 'Rococo')
# ('Semper Augustus Tulips in a Wan-Li Vase', 'Ambrosius Bosschaert', 'Rococo')
# ('Still Life with Flowers', 'Ambrosius Bosschaert', 'Rococo')
# ('Tulips, Roses, Bluebells, Narcissus Tortuosis', 'Ambrosius Bosschaert', 'Rococo')
# ('A Young Man Drinking', 'Bartolomé Esteban Murillo', 'Baroque')
# ('Boy with a Dog', 'Bartolomé Esteban Murillo', 'Baroque')
# ('Christ Bearing the Cross', 'Bartolomé Esteban Murillo', 'Baroque')
# ('The Mystic Marriage of Saint Catherine', 'Bartolomé Esteban Murillo', 'Baroque')
# ('The Vision of Saint Francis of Paola', 'Bartolomé Esteban Murillo', 'Baroque')
# ("The Young Beggar (The Beggar's Toilet)", 'Bartolomé Esteban Murillo', 'Baroque')
# ('Two Women at a Window', 'Bartolomé Esteban Murillo', 'Baroque')
# ('A Young Woman Warming Her Hands Over a Brazier', 'Caesar Van Everdingen', 'Baroque')
# ('Elisabeth Van Kessel (1640-1717), Wife of Willem Jacobsz Baert', 'Caesar Van Everdingen', 'Baroque')
# ('Girl in a Large Hat', 'Caesar Van Everdingen', 'Baroque')
# ('Pan and Syrinx', 'Caesar Van Everdingen', 'Baroque')
# ('Vertumnus and Pomona', 'Caesar Van Everdingen', 'Baroque')
# ('Willem Jacobsz Baert (1636-84), Burgomaster of Alkmaar and Amsterdam', 'Caesar Van Everdingen', 'Baroque')
# ('Woman Praying', 'Caesar Van Everdingen', 'Baroque')
# ('Alof de Vignacourt and His Page', 'Caravaggio', 'Baroque')
# ('Amor Victorious', 'Caravaggio', 'Baroque')
# ('Boy Bitten by a Lizard', 'Caravaggio', 'Baroque')
# ('Boy with a Basket of Fruit', 'Caravaggio', 'Baroque')
# ('Christ at the Column', 'Caravaggio', 'Baroque')
# ('Conversion on the Way to Damascus', 'Caravaggio', 'Baroque')
# ('David and Goliath', 'Caravaggio', 'Baroque')
# ('David with the Head of Goliath', 'Caravaggio', 'Baroque')
# ('Ecce Homo', 'Caravaggio', 'Baroque')
# ('John the Baptist', 'Caravaggio', 'Baroque')
# ('Judith Beheading Holofernes', 'Caravaggio', 'Baroque')
# ('Madonna with the Serpent', 'Caravaggio', 'Baroque')
# ('Martha and Mary Magdalene', 'Caravaggio', 'Baroque')
# ('Narcissus', 'Caravaggio', 'Baroque')
# ('Portrait of Pope Urban VIII (Maffeo Barberini)', 'Caravaggio', 'Baroque')
# ('Rest on the Flight into Egypt', 'Caravaggio', 'Baroque')
# ('Saint Francis in Prayer', 'Caravaggio', 'Baroque')
# ('Saint Gerome Writing', 'Caravaggio', 'Baroque')
# ('Saint Jerome in His Study', 'Caravaggio', 'Baroque')
# ('Saint Jerome Penitent', 'Caravaggio', 'Baroque')
# ('Saint John the Baptist', 'Caravaggio', 'Baroque')
# ('Salome Receives the Head of Saint John the Baptist', 'Caravaggio', 'Baroque')
# ('Supper at Emmaus', 'Caravaggio', 'Baroque')
# ('The Beheading of Saint John the Baptist', 'Caravaggio', 'Baroque')
# ('The Calling of Saint Matthew', 'Caravaggio', 'Baroque')
# ('The Cardsharps', 'Caravaggio', 'Baroque')
# ('The Crowning with Thorns', 'Caravaggio', 'Baroque')
# ('The Crucifixion of Saint Andrew', 'Caravaggio', 'Baroque')
# ('The Crucifixion of Saint Peter', 'Caravaggio', 'Baroque')
# ('The Denial of Saint Peter', 'Caravaggio', 'Baroque')
# ('The Incredulity of Saint Thomas', 'Caravaggio', 'Baroque')
# ('The Inspiration of Saint Matthew', 'Caravaggio', 'Baroque')
# ('The Musicians', 'Caravaggio', 'Baroque')
# ('The Young Bacchus', 'Caravaggio', 'Baroque')
# ('A Young Man in a Fur Cap and a Cuirass', 'Carel Fabritius', 'Baroque')
# ('Mercury, Argus, and Io', 'Carel Fabritius', 'Baroque')
# ('Portrait of Van Abraham de Potter', 'Carel Fabritius', 'Baroque')
# ('The Goldfinch', 'Carel Fabritius', 'Baroque')
# ('Aeneas in Delos', 'Claude Lorrain', 'Baroque')
# ('An Artist Studying from Nature', 'Claude Lorrain', 'Baroque')
# ('Capriccio with Ruins of the Roman Forum', 'Claude Lorrain', 'Baroque')
# ('Coast View with the Abduction of Europa', 'Claude Lorrain', 'Baroque')
# ('Embarkation of St. Paula', 'Claude Lorrain', 'Baroque')
# ('Landscape with Acis and Galatea', 'Claude Lorrain', 'Baroque')
# ('Landscape with Dancing Satyrs and Nymphs', 'Claude Lorrain', 'Baroque')
# ('Landscape with Merchants', 'Claude Lorrain', 'Baroque')
# ('Landscape with Nymph and Satyr Dancing', 'Claude Lorrain', 'Baroque')
# ('Landscape with the Embarkment of Saint Paula Romana in Ostia', 'Claude Lorrain', 'Baroque')
# ('Pastoral Landscape with a Mill', 'Claude Lorrain', 'Baroque')
# ('Rape of Europa', 'Claude Lorrain', 'Baroque')
# ('Seaport with the Embarkation of Saint Ursula', 'Claude Lorrain', 'Baroque')
# ('Seaport with the Embarkation of the Queen of Sheba', 'Claude Lorrain', 'Baroque')
# ('The Judgment of Paris', 'Claude Lorrain', 'Baroque')
# ('The Trojan Women Setting Fire to Their Fleet', 'Claude Lorrain', 'Baroque')
# ('View of a Port with the Capitol by Jelly', 'Claude Lorrain', 'Baroque')
# ('Villa in the Roman Campagna', 'Claude Lorrain', 'Baroque')
# ('Dirck Volkertsz Coornhert, Writer and Engraver', 'Cornelis Van Haarlem', 'Baroque')
# ('Pomona Receiving the Harvest of Fruit', 'Cornelis Van Haarlem', 'Baroque')
# ('The Fall of Man', 'Cornelis Van Haarlem', 'Baroque')
# ('The Massacre of the Innocents', 'Cornelis Van Haarlem', 'Baroque')
# ("A Doctor Tending a Patient's Foot in His Surgery", 'David Teniers', 'Baroque')
# ('An Old Woman Peeling Pears', 'David Teniers', 'Baroque')
# ('An Old Woman Reading', 'David Teniers', 'Baroque')
# ('Game of Backgammon', 'David Teniers', 'Baroque')
# ('Guardroom with the Deliverance of Saint Peter', 'David Teniers', 'Baroque')
# ('Judith with the Head of Holofernes', 'David Teniers', 'Baroque')
# ('Kitchen Interior', 'David Teniers', 'Baroque')
# ('Landscape with Peasants Dancing', 'David Teniers', 'Baroque')
# ('Landscape with Peasants Playing Bowls Outside an Inn', 'David Teniers', 'Baroque')
# ('Old Man and Woman', 'David Teniers', 'Baroque')
# ('Peasants Dancing and Feasting', 'David Teniers', 'Baroque')
# ('Peasants Smoking in an Inn', 'David Teniers', 'Baroque')
# ('Personification of Autumn', 'David Teniers', 'Baroque')
# ('The Alchemist', 'David Teniers', 'Baroque')
# ('The Smoker', 'David Teniers', 'Baroque')
# ('A Dwarf Sitting on the Floor', 'Diego Velázquez', 'Baroque')
# ('A Venus at Her Mirror', 'Diego Velázquez', 'Baroque')
# ('Allegorical Portrait of Philip IV', 'Diego Velázquez', 'Baroque')
# ('Arachne, A Sybil', 'Diego Velázquez', 'Baroque')
# ('Christ Crucified', 'Diego Velázquez', 'Baroque')
# ('Count Duke of Olivares on Horseback', 'Diego Velázquez', 'Baroque')
# ('Fernando de Valdes y Llanos', 'Diego Velázquez', 'Baroque')
# ('Infanta Dona Maria, Queen of Hungary', 'Diego Velázquez', 'Baroque')
# ('Infanta Margarita III', 'Diego Velázquez', 'Baroque')
# ('Infanta Margarita in a Blue Dress', 'Diego Velázquez', 'Baroque')
# ('Infanta Margarita in Pink and Silver', 'Diego Velázquez', 'Baroque')
# ('Infanta Maria Teresa', 'Diego Velázquez', 'Baroque')
# ('John the Evangelist from Patmos', 'Diego Velázquez', 'Baroque')
# ('Juan de Pareja', 'Diego Velázquez', 'Baroque')
# ('Kitchen Scene with Christ in the House of Martha and Mary', 'Diego Velázquez', 'Baroque')
# ('Las Meninas', 'Diego Velázquez', 'Baroque')
# ('Old Woman Poaching Eggs', 'Diego Velázquez', 'Baroque')
# ('Peasants at a Table', 'Diego Velázquez', 'Baroque')
# ('Philip IV, King of Spain', 'Diego Velázquez', 'Baroque')
# ('Philip IV of Spain', 'Diego Velázquez', 'Baroque')
# ('Pope Innocent X', 'Diego Velázquez', 'Baroque')
# ('Prince Balthasar Carlos on Horseback', 'Diego Velázquez', 'Baroque')
# ('Prince Felipe Prospero', 'Diego Velázquez', 'Baroque')
# ('The Buffoon Calabazas', 'Diego Velázquez', 'Baroque')
# ('The Needlewoman', 'Diego Velázquez', 'Baroque')
# ('The Supper at Emmaus', 'Diego Velázquez', 'Baroque')
# ('The Surrender of Breda', 'Diego Velázquez', 'Baroque')
# ('The Waterseller of Seville', 'Diego Velázquez', 'Baroque')
# ('Three Musicians, Musical Trio', 'Diego Velázquez', 'Baroque')
# ('A Lady with a Fan', 'Ferdinand Bol', 'Baroque')
# ('An Astronomer', 'Ferdinand Bol', 'Baroque')
# ('Lieutenant-Admiral Michiel de Ruyter', 'Ferdinand Bol', 'Baroque')
# ('A Cup of Water and a Rose', 'Francisco De Zurbarán', 'Baroque')
# ('Childhood of the Virgin', 'Francisco De Zurbarán', 'Baroque')
# ('Christ and the Virgin in the House at Nazareth', 'Francisco De Zurbarán', 'Baroque')
# ('Crucifixion', 'Francisco De Zurbarán', 'Baroque')
# ('Inmaculada Concepcion', 'Francisco De Zurbarán', 'Baroque')
# ('Portrait of Doctor Juan Martine Serrano', 'Francisco De Zurbarán', 'Baroque')
# ('Portrait of Two Girls', 'Francisco De Zurbarán', 'Baroque')
# ('Regina Angelorum', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Dorothy Holding a Basket of Apples and Roses', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Elizabeth of Thuringia', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Francis in Meditation', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Francis of Assisi in Prayer', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Luke as a Painter', 'Francisco De Zurbarán', 'Baroque')
# ('Saint Serapius', 'Francisco De Zurbarán', 'Baroque')
# ('Saints Agatha, Lucy and Apollonia', 'Francisco De Zurbarán', 'Baroque')
# ('San Francisco in Meditation', 'Francisco De Zurbarán', 'Baroque')
# ('St. Francis in Meditation', 'Francisco De Zurbarán', 'Baroque')
# ('St. Margaret', 'Francisco De Zurbarán', 'Baroque')
# ('The Archangel Michael Vanquishing the Devil', 'Francisco De Zurbarán', 'Baroque')
# ('The Archangel Michael', 'Francisco De Zurbarán', 'Baroque')
# ('The Defense of Cadiz Against the English', 'Francisco De Zurbarán', 'Baroque')
# ('The Immaculate Conception', 'Francisco De Zurbarán', 'Baroque')
# ('The Lamb of God', 'Francisco De Zurbarán', 'Baroque')
# ('The Mystic Marriage of Saint Catherine of Alexandria', 'Francisco De Zurbarán', 'Baroque')
# ('The Penitent Saint Peter', 'Francisco De Zurbarán', 'Baroque')
# ('The Veil of Saint Veronica', 'Francisco De Zurbarán', 'Baroque')
# ('The Virgin with the Child Jesus and the Child Saint John the Baptist', 'Francisco De Zurbarán', 'Baroque')
# ('The Young Virgin', 'Francisco De Zurbarán', 'Baroque')
# ('A Visit to the Art Dealer', 'Frans Francken', 'Baroque')
# ('Ahasver and Haman at the Banquet of Esther', 'Frans Francken', 'Baroque')
# ('Allegory on the Abdication of Emperor Charles V in Brussels', 'Frans Francken', 'Baroque')
# ('Arcadia the Golden Age', 'Frans Francken', 'Baroque')
# ('Interior Called Rubens Salon', 'Frans Francken', 'Baroque')
# ('Kronsus Shows Solon His Treasures', 'Frans Francken', 'Baroque')
# ('Landscape with Allegories of the Four Elements', 'Frans Francken', 'Baroque')
# ('The Adbuction of Helen', 'Frans Francken', 'Baroque')
# ('The Crucifixion of St. Andrew', 'Frans Francken', 'Baroque')
# ('The Death of Death', 'Frans Francken', 'Baroque')
# ('The Idolatry of Solomon', 'Frans Francken', 'Baroque')
# ('A Family Group in a Landscape', 'Frans Hals', 'Baroque')
# ('Adriaen Van Ostade', 'Frans Hals', 'Baroque')
# ('Amme with the Child', 'Frans Hals', 'Baroque')
# ('Boy with a Lute', 'Frans Hals', 'Baroque')
# ('Boy with a Skull', 'Frans Hals', 'Baroque')
# ('Buffoon Playing a Lute', 'Frans Hals', 'Baroque')
# ('Claes Duyst Van Voorhout', 'Frans Hals', 'Baroque')
# ('Feyntje Van Steenkiste', 'Frans Hals', 'Baroque')
# ('Fisher Boy', 'Frans Hals', 'Baroque')
# ('Jonker Ramp and His Sweetheart', 'Frans Hals', 'Baroque')
# ('Malle Babbe', 'Frans Hals', 'Baroque')
# ('Marriage Portrait of Isaac Massa and Beatrix Van Der Laen', 'Frans Hals', 'Baroque')
# ('Merrymakers at Shrovetide', 'Frans Hals', 'Baroque')
# ("Militia Company of District XI, Known as 'The Meagre Company'", 'Frans Hals', '\\N')
# ('Paulus Verschuur', 'Frans Hals', 'Baroque')
# ('Peeckelhaering', 'Frans Hals', 'Baroque')
# ('Portrait of a Dutch Family', 'Frans Hals', 'Baroque')
# ('Portrait of a Gentleman in White', 'Frans Hals', 'Baroque')
# ('Portrait of a Gentlemen', 'Frans Hals', 'Baroque')
# ('Portrait of a Man Holding a Watch', 'Frans Hals', 'Baroque')
# ('Portrait of a Man Holding Gloves', 'Frans Hals', 'Baroque')
# ('Portrait of a Man in His Thirties', 'Frans Hals', 'Baroque')
# ('Portrait of a Man, possibly a Clergyman', 'Frans Hals', 'Baroque')
# ('Portrait of a Man, Possibly Nicolaes Hasselaer', 'Frans Hals', 'Baroque')
# ('Portrait of a Member of the Haarlem Civic Guard', 'Frans Hals', 'Baroque')
# ('Portrait of a Middle-Aged Woman with Hands Folded', 'Frans Hals', 'Baroque')
# ('Portrait of a Woman Holding a Fan', 'Frans Hals', 'Baroque')
# ('Portrait of a Woman, Possibly Sara Wolphaerts Van Diemen', 'Frans Hals', 'Baroque')
# ('Portrait of an Old Woman', 'Frans Hals', 'Baroque')
# ('Portrait of Isaac Abrahamsz Massa', 'Frans Hals', 'Baroque')
# ('Portrait of Jean de la Chambre at the Age of 33', 'Frans Hals', 'Baroque')
# ('Portrait of Lucas de Clercq', 'Frans Hals', 'Baroque')
# ('Portrait of Maritge Claesdr Vooght', 'Frans Hals', 'Baroque')
# ('Portrait of Maritge Voogt Claesdr', 'Frans Hals', 'Baroque')
# ('Portrait of Pieter Jacobsz Olycan at Bust Length', 'Frans Hals', 'Baroque')
# ('Portrait of Tieleman Roosterman', 'Frans Hals', 'Baroque')
# ('Portrait of Willem Van Heythuysen', 'Frans Hals', 'Baroque')
# ('Samuel Ampzing', 'Frans Hals', 'Baroque')
# ('Singing Boy with a Flute', 'Frans Hals', 'Baroque')
# ('The Gypsy Girl', 'Frans Hals', 'Baroque')
# ('The Laughing Cavalier', 'Frans Hals', 'Baroque')
# ('The Merry Drinker', 'Frans Hals', 'Baroque')
# ('The Rommel Pot Player', 'Frans Hals', 'Baroque')
# ('Two Boys Singing', 'Frans Hals', 'Baroque')
# ('Violin Player in a Dune Landscape', 'Frans Hals', 'Baroque')
# ('Willem Coenraetsz Coymans', 'Frans Hals', 'Baroque')
# ('Brazilian Village', 'Frans Jansz Post', 'Baroque')
# ('Landscape on the Rio Senhor de Engenho, Brazil', 'Frans Jansz Post', 'Baroque')
# ('View of Olinda, Brazil', 'Frans Jansz Post', 'Baroque')
# ('View of the Island of Itamaraca´, Brazil', 'Frans Jansz Post', 'Baroque')
# ('A Woman Seated at a Table and a Man Tuning a Violin', 'Gabrie¨l Metsu', 'Baroque')
# ('A Young Woman Seated Drawing', 'Gabrie¨l Metsu', 'Baroque')
# ('Man and Woman at a Meal', 'Gabrie¨l Metsu', 'Baroque')
# ('Old Woman Meditating', 'Gabrie¨l Metsu', 'Baroque')
# ('The Herring-Seller', 'Gabrie¨l Metsu', 'Baroque')
# ('The Hunter’s Present', 'Gabrie¨l Metsu', 'Baroque')
# ('The Music Lesson', 'Gabrie¨l Metsu', 'Baroque')
# ('The Old Drinker', 'Gabrie¨l Metsu', 'Baroque')
# ('The Sick Child', 'Gabrie¨l Metsu', 'Baroque')
# ('The Weaponsmith', 'Gabrie¨l Metsu', 'Baroque')
# ('Woman Eating, Known as The Cat’s Breakfast', 'Gabrie¨l Metsu', 'Baroque')
# ('Joseph the Carpenter', 'Georges De La Tour', 'Baroque')
# ('Magdalene with the Nightlight', 'Georges De La Tour', 'Baroque')
# ('The Adoration of the Shepherds', 'Georges De La Tour', 'Baroque')
# ('The Cheat with the Ace of Diamonds', 'Georges De La Tour', 'Baroque')
# ('The Education of the Virgin', 'Georges De La Tour', 'Baroque')
# ('The Fortune Teller', 'Georges De La Tour', 'Baroque')
# ('The Musicians Brawl', 'Georges De La Tour', 'Baroque')
# ('The Penitent Magdalen', 'Georges De La Tour', 'Baroque')
# ('A Boy Defleaing a Dog', 'Gerard Ter Borch', 'Baroque')
# ('A Maid Milking a Cow in a Barn', 'Gerard Ter Borch', 'Baroque')
# ('A Woman Playing a Theorbo to Two Men', 'Gerard Ter Borch', 'Baroque')
# ('A Woman Playing the Theorbo-Lute and a Cavalier', 'Gerard Ter Borch', 'Baroque')
# ('A Young Woman at Her Toilet with a Maid', 'Gerard Ter Borch', 'Baroque')
# ('Aletta Pancras, Wife of Francois de Vicq', 'Gerard Ter Borch', 'Baroque')
# ('An Officer Dictating a Letter', 'Gerard Ter Borch', 'Baroque')
# ('Burgomaster Jan Van Duren', 'Gerard Ter Borch', 'Baroque')
# ('Curiosity', 'Gerard Ter Borch', 'Baroque')
# ('Dancing Couple', 'Gerard Ter Borch', 'Baroque')
# ('Francois de Vicq, Burgomaster of Amsterdam', 'Gerard Ter Borch', 'Baroque')
# ('Helena Van Der Schalcke', 'Gerard Ter Borch', 'Baroque')
# ('Horse Stable', 'Gerard Ter Borch', 'Baroque')
# ('Lady Seated Holding a Wineglass', 'Gerard Ter Borch', 'Baroque')
# ('Margaretha Van Haexbergen', 'Gerard Ter Borch', 'Baroque')
# ('Memorial Portrait of Moses Ter Borch', 'Gerard Ter Borch', 'Baroque')
# ('Officer Writing a Letter, with a Trumpeter', 'Gerard Ter Borch', 'Baroque')
# ('Portrait of a Seated Man', 'Gerard Ter Borch', 'Baroque')
# ('Portrait of Hermanna Van Der Cruis', 'Gerard Ter Borch', 'Baroque')
# ('Seated Girl in Peasant Costume', 'Gerard Ter Borch', 'Baroque')
# ('The Paternal Admonition', 'Gerard Ter Borch', 'Baroque')
# ("The Suitor's Visit", 'Gerard Ter Borch', 'Baroque')
# ('The Van Moerkerken Family', 'Gerard Ter Borch', 'Baroque')
# ('Woman at a Mirror', 'Gerard Ter Borch', 'Baroque')
# ('Christ Before the High Priest', 'Gerard Van Honthorst', 'Baroque')
# ('Elizabeth Stuart, Queen of Bohemia', 'Gerard Van Honthorst', 'Baroque')
# ('Frederick Henry, His Consort Amalia of Solms, and their Three Youngest Daughters', 'Gerard Van Honthorst', 'Baroque')
# ('Musical Group on a Balcony', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Amalia van Solms', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Frederick Henry, Prince of Orange', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Frederik Hendrik, Prince of Orange', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Friedrich Wilhelm, Elector of Brandenburg, and His Wife Louise Henriette, Countess of Orange-Nassau', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Willem II, Prince of Orange, and His Wife Mary Stuart', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of Willem II, Prince of Orange', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of William II, Prince of Orange', 'Gerard Van Honthorst', 'Baroque')
# ('Portrait of William III, Prince of Orange', 'Gerard Van Honthorst', 'Baroque')
# ('Saint Sebastian', 'Gerard Van Honthorst', 'Baroque')
# ('Samson and Delilah', 'Gerard Van Honthorst', 'Baroque')
# ('Satyr and Nymph', 'Gerard Van Honthorst', 'Baroque')
# ('Shepherd Playing the Flute, and Four Shepherdesses', 'Gerard Van Honthorst', 'Baroque')
# ('The Merry Fiddler', 'Gerard Van Honthorst', 'Baroque')
# ('The Mocking of Christ', 'Gerard Van Honthorst', 'Baroque')
# ("A Poulterer's Shop", 'Gerrit Dou', 'Baroque')
# ('A Young Woman at Her Toilet', 'Gerrit Dou', 'Baroque')
# ('Girl Chopping Onions', 'Gerrit Dou', 'Baroque')
# ('Maidservant at a Window', 'Gerrit Dou', 'Baroque')
# ('Parable of the Hidden Treasure', 'Gerrit Dou', 'Baroque')
# ('Portrait of a Couple in a Landscape', 'Gerrit Dou', 'Baroque')
# ('Portrait of an Old Woman Reading', 'Gerrit Dou', 'Baroque')
# ('The Night School', 'Gerrit Dou', 'Baroque')
# ('The Quack', 'Gerrit Dou', 'Baroque')
# ('Woman Eating Porridge', 'Gerrit Dou', 'Baroque')
# ('Young Woman Holding a Lamp', 'Gerrit Dou', 'Baroque')
# ('Bacchus and Ariadne', 'Guido Reni', 'Baroque')
# ('Cardinal Roberto Ubaldini, Papal Legate to Bologna', 'Guido Reni', 'Baroque')
# ('Christ Embracing Saint John the Baptist', 'Guido Reni', 'Baroque')
# ("Joseph and Potiphar's Wife", 'Guido Reni', 'Baroque')
# ('Lot and His Daughters Leaving Sodom', 'Guido Reni', 'Baroque')
# ('Saint Jerome', 'Guido Reni', 'Baroque')
# ('St. Mary Magdalene', 'Guido Reni', 'Baroque')
# ('Susannah and the Elders', 'Guido Reni', 'Baroque')
# ('The Coronation of the Virgin', 'Guido Reni', 'Baroque')
# ('The Toilet of Venus', 'Guido Reni', 'Baroque')
# ('Virgin and Child with Saint John the Baptist', 'Guido Reni', 'Baroque')
# ('A Scene on the Ice Near a Town', 'Hendrick Avercamp', 'Baroque')
# ('A Scene on the Ice', 'Hendrick Avercamp', 'Baroque')
# ('Enjoying the Ice Near a Town', 'Hendrick Avercamp', 'Baroque')
# ('Enjoying the Ice', 'Hendrick Avercamp', 'Baroque')
# ('Kolfplayers on Ice', 'Hendrick Avercamp', 'Baroque')
# ('On the Ice', 'Hendrick Avercamp', 'Baroque')
# ('Winter Landscape with a Hunter Shooting Duck', 'Hendrick Avercamp', 'Baroque')
# ('Winter Landscape with Ice Skaters', 'Hendrick Avercamp', 'Baroque')
# ('Winter Scene on a Frozen Canal', 'Hendrick Avercamp', 'Baroque')
# ('A Lute Player', 'Hendrick Ter Brugghen', 'Baroque')
# ('Bacchante with an Ape', 'Hendrick Ter Brugghen', 'Baroque')
# ('Jacob Reproaching Laban', 'Hendrick Ter Brugghen', 'Baroque')
# ('Man Playing a Lute', 'Hendrick Ter Brugghen', 'Baroque')
# ('The Concert', 'Hendrick Ter Brugghen', 'Baroque')
# ('A Winter Scene', 'Isaac Van Ostade', 'Baroque')
# ('An Inn by a Frozen River', 'Isaac Van Ostade', 'Baroque')
# ('A Landscape with a Ruined Building', 'Jacob Van Ruisdael', 'Baroque')
# ('A Landscape with a Ruined Castle and a Church', 'Jacob Van Ruisdael', 'Baroque')
# ('A Panoramic View of Amsterdam Looking Towards-the-Ij', 'Jacob Van Ruisdael', 'Baroque')
# ('A Ruined Castle Gateway', 'Jacob Van Ruisdael', 'Baroque')
# ('A Waterfall at the Foot of a Hill Near a Village', 'Jacob Van Ruisdael', 'Baroque')
# ('A Waterfall in a Rocky Landscape', 'Jacob Van Ruisdael', 'Baroque')
# ('Bentheim Castle', 'Jacob Van Ruisdael', 'Baroque')
# ('Bridge with a Sluice', 'Jacob Van Ruisdael', 'Baroque')
# ('Landscape with a Church by a Torrent', 'Jacob Van Ruisdael', 'Baroque')
# ('Landscape with a Wheatfield', 'Jacob Van Ruisdael', 'Baroque')
# ('Landscape with Waterfall', 'Jacob Van Ruisdael', 'Baroque')
# ('Mountain Torrent', 'Jacob Van Ruisdael', 'Baroque')
# ('The Great Oak', 'Jacob Van Ruisdael', 'Baroque')
# ('The Shore at Egmond Aan Zee', 'Jacob Van Ruisdael', 'Baroque')
# ('The Windmill at Wijk bij Duurstede', 'Jacob Van Ruisdael', 'Baroque')
# ('Three Watermills with Washerwomen', 'Jacob Van Ruisdael', 'Baroque')
# ('Two Watermills and an Open Sluice at Singraven', 'Jacob Van Ruisdael', 'Baroque')
# ('Two Watermills and an Open Sluice', 'Jacob Van Ruisdael', 'Baroque')
# ('Vessels in a Fresh Breeze', 'Jacob Van Ruisdael', 'Baroque')
# ('View of Grainfields with a Distant Town', 'Jacob Van Ruisdael', 'Baroque')
# ('View of Haarlem from the Northwest, with the Bleaching Fields in the Foreground', 'Jacob Van Ruisdael', 'Baroque')
# ('View of the River Lek and Vianen', 'Jacob Van Ruisdael', 'Baroque')
# ('Wooded and Hilly Landscape', 'Jacob Van Ruisdael', 'Baroque')
# ('A Landscape with the Judgement of Paris', 'Jan Both', 'Baroque')
# ('A Rocky Italian Landscape with Herdsmen and Muleteers', 'Jan Both', 'Baroque')
# ('A Rocky Landscape with an Ox-cart', 'Jan Both', 'Baroque')
# ('A View on the Tiber', 'Jan Both', 'Baroque')
# ('Farmyard', 'Jan Both', 'Baroque')
# ('Italian Landscape with a Draughtsman', 'Jan Both', 'Baroque')
# ('Italian Landscape with a View of a Harbor', 'Jan Both', 'Baroque')
# ('Italian Landscape with Ferry', 'Jan Both', 'Baroque')
# ('Italian Landscape with the Ponte Molle', 'Jan Both', 'Baroque')
# ('Landscape with a Draftsman', 'Jan Both', 'Baroque')
# ('Men with an Ox and Cattle by a Pool', 'Jan Both', 'Baroque')
# ('Peasants with Mules and Oxen', 'Jan Both', 'Baroque')
# ('Street Scene Placed Among Roman Ruins', 'Jan Both', 'Baroque')
# ('A Young Man and Woman Making Music', 'Jan Miense Molenaer', 'Baroque')
# ('Allegory of Vanity', 'Jan Miense Molenaer', 'Baroque')
# ('Artist in His Studio', 'Jan Miense Molenaer', 'Baroque')
# ('Painter in His Studio', 'Jan Miense Molenaer', 'Baroque')
# ('The Five Senses, Hearing', 'Jan Miense Molenaer', 'Baroque')
# ('The Five Senses, Sight', 'Jan Miense Molenaer', 'Baroque')
# ('The Five Senses, Smell', 'Jan Miense Molenaer', 'Baroque')
# ('The Five Senses, Taste', 'Jan Miense Molenaer', 'Baroque')
# ('The Five Senses, Touch', 'Jan Miense Molenaer', 'Baroque')
# ('Three Children Drinking and Making Mischief', 'Jan Miense Molenaer', 'Baroque')
# ('Two Boys and a Girl Making Music', 'Jan Miense Molenaer', 'Baroque')
# ('A Man Blowing Smoke at Drunken Woman', 'Jan Steen', 'Baroque')
# ('A Peasant Family at Meal Time Grace Before Meat', 'Jan Steen', 'Baroque')
# ('A Pedlar Selling Spectacles Outside a Cottage', 'Jan Steen', 'Baroque')
# ('A Young Woman Playing a Harpsichord to a Young Man', 'Jan Steen', 'Baroque')
# ('Adolf and Catharina Croeser, The Burgomaster of Delft and His Daughter', 'Jan Steen', 'Baroque')
# ('An Interior with a Man Offering an Oyster to a Woman', 'Jan Steen', 'Baroque')
# ('Bathsheba After the Bath', 'Jan Steen', 'Baroque')
# ('Children Teaching a Cat to Dance', 'Jan Steen', 'Baroque')
# ('Family Scene', 'Jan Steen', 'Baroque')
# ('Interior with a Woman Feeding a Parrot', 'Jan Steen', 'Baroque')
# ('Man with a Fiddle in Bad Company', 'Jan Steen', 'Baroque')
# ('Prince’s Day', 'Jan Steen', 'Baroque')
# ('The Baker Arent Oostwaard and His Wife, Catharina Keizerswaard', 'Jan Steen', 'Baroque')
# ('The Bowlers', 'Jan Steen', 'Baroque')
# ('The Drawing Lesson', 'Jan Steen', 'Baroque')
# ('The Drunken Couple', 'Jan Steen', 'Baroque')
# ('The Effects of Intemperance', 'Jan Steen', 'Baroque')
# ('The Feast of St. Nicholas', 'Jan Steen', 'Baroque')
# ('The Merry Family', 'Jan Steen', 'Baroque')
# ('The Merry Homecoming', 'Jan Steen', 'Baroque')
# ('The Sick Woman', 'Jan Steen', 'Baroque')
# ('Two Men and a Young Woman Making Music on a Terrace', 'Jan Steen', 'Baroque')
# ('Woman at Her Toilet', 'Jan Steen', 'Baroque')
# ('Woman Scouring Metalware', 'Jan Steen', 'Baroque')
# ('A Cottage on a Heath', 'Jan Van Goyen', 'Baroque')
# ('A River Landscape', 'Jan Van Goyen', 'Baroque')
# ('A River Scene with a Hut on an Island', 'Jan Van Goyen', 'Baroque')
# ('A River Scene with Fishermen Laying a Net', 'Jan Van Goyen', 'Baroque')
# ('A Scene on the Ice near Dordrecht', 'Jan Van Goyen', 'Baroque')
# ('A Windmill by a River', 'Jan Van Goyen', 'Baroque')
# ('An Estuary with Fishing Boats and Two Frigates', 'Jan Van Goyen', 'Baroque')
# ('River View with a Village Church', 'Jan Van Goyen', 'Baroque')
# ('Sailing Vessels on a River in a Breeze', 'Jan Van Goyen', 'Baroque')
# ('The Mouth of an Estuary with a Gateway', 'Jan Van Goyen', 'Baroque')
# ('The Pelkus Gate near Ultrecht', 'Jan Van Goyen', 'Baroque')
# ('The Square Watch-Tower', 'Jan Van Goyen', 'Baroque')
# ('View of Arnhem', 'Jan Van Goyen', 'Baroque')
# ('View of Dordrecht', 'Jan Van Goyen', 'Baroque')
# ('View of Duurstede Castle at Wijk bij Duurstede', 'Jan Van Goyen', 'Baroque')
# ('A Lady and Two Gentlemen', 'Johannes Vermeer', 'Baroque')
# ('A Lady Writing a Letter', 'Johannes Vermeer', 'Baroque')
# ('A Maid Asleep', 'Johannes Vermeer', 'Baroque')
# ('Christ in the House of Mary and Martha', 'Johannes Vermeer', 'Baroque')
# ('Girl Interrupted at Her Music', 'Johannes Vermeer', 'Baroque')
# ('Girl Reading a Letter at an Open Window', 'Johannes Vermeer', 'Baroque')
# ('Girl with a Flute', 'Johannes Vermeer', 'Baroque')
# ('Girl with a Pearl Earring', 'Johannes Vermeer', 'Baroque')
# ('Girl with a Red Hat', 'Johannes Vermeer', 'Baroque')
# ('Lady Seated at a Virginal', 'Johannes Vermeer', 'Baroque')
# ('Lady Writing a Letter with Her Maid', 'Johannes Vermeer', 'Baroque')
# ('Mistress and Maid', 'Johannes Vermeer', 'Baroque')
# ('Officer with a Laughing Girl', 'Johannes Vermeer', 'Baroque')
# ('The Allegory of Faith', 'Johannes Vermeer', 'Baroque')
# ('The Art of Painting', 'Johannes Vermeer', 'Baroque')
# ('The Astronomer', 'Johannes Vermeer', 'Baroque')
# ('The Geographer', 'Johannes Vermeer', 'Baroque')
# ('The Glass of Wine', 'Johannes Vermeer', 'Baroque')
# ('The Guitar Player', 'Johannes Vermeer', 'Baroque')
# ('The Lacemaker', 'Johannes Vermeer', 'Baroque')
# ('The Milkmaid', 'Johannes Vermeer', 'Baroque')
# ('View of Delft', 'Johannes Vermeer', 'Baroque')
# ('View of Houses in Delft', 'Johannes Vermeer', 'Baroque')
# ('Woman Holding a Balance', 'Johannes Vermeer', 'Baroque')
# ('Woman in Blue Reading a Letter', 'Johannes Vermeer', 'Baroque')
# ('Woman with a Lute Near a Window', 'Johannes Vermeer', 'Baroque')
# ('Woman with a Pearl Necklace', 'Johannes Vermeer', 'Baroque')
# ('Young Woman Standing at a Virginal', 'Johannes Vermeer', 'Baroque')
# ('Young Woman with a Water Pitcher', 'Johannes Vermeer', 'Baroque')
# ('A Deer Chased by Dogs', 'Jean-Baptiste Oudry', 'Baroque')
# ('A Hare and a Leg of Lamb', 'Jean-Baptiste Oudry', 'Baroque')
# ('A Landscape with a Brace of Partridges and a Hare', 'Jean-Baptiste Oudry', 'Baroque')
# ('Cassowary', 'Jean-Baptiste Oudry', 'Baroque')
# ('Clara the Rhinoceros in Paris in 1749', 'Jean-Baptiste Oudry', 'Baroque')
# ("Corner of Monsieur de la Bruyere's Garden", 'Jean-Baptiste Oudry', 'Baroque')
# ('Dog Guarding Dead Game', 'Jean-Baptiste Oudry', 'Baroque')
# ('Don Jose de Rozas y Melendez de la Cueva, 1st Count of Castelblanco', 'Jean-Baptiste Oudry', 'Baroque')
# ('Ducks Resting in Sunshine', 'Jean-Baptiste Oudry', 'Baroque')
# ('Greyhound in a Landscape', 'Jean-Baptiste Oudry', 'Baroque')
# ('Henri Camille, Chevalier de Beringhen', 'Jean-Baptiste Oudry', 'Baroque')
# ('Hunting Still Life with a Hare, Partridges and Pheasants', 'Jean-Baptiste Oudry', 'Baroque')
# ('Leopard in a Cage Confronted by Two Mastiffs', 'Jean-Baptiste Oudry', 'Baroque')
# ("L'hallali du Loup", 'Jean-Baptiste Oudry', 'Baroque')
# ("L'Oranger", 'Jean-Baptiste Oudry', 'Baroque')
# ('Misse and Luttine', 'Jean-Baptiste Oudry', 'Baroque')
# ('Portrait of a Sportsman Holding a Gun with a Hound', 'Jean-Baptiste Oudry', 'Baroque')
# ('Portrait of Maria Josefa Drummond', 'Jean-Baptiste Oudry', 'Baroque')
# ('Still Life of a Songbird and Butterflies', 'Jean-Baptiste Oudry', 'Baroque')
# ('Still Life of Fruits and Vegetables', 'Jean-Baptiste Oudry', 'Baroque')
# ('Still Life wth a Dead Roe and Cardoons', 'Jean-Baptiste Oudry', 'Baroque')
# ('Still Life wth a Violin, a Recorder, Books, a Portfolio of Sheet of Music, Peaches and Grapes', 'Jean-Baptiste Oudry', 'Baroque')
# ('Swan Attacked by a Dog', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Bag, a Dead Deer, Two Falcons and a Heron', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Dachshound Pehr with Dead Game and Rifle', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Dog Carring His Dinner to His Master', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Lion and the Fly', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Watchful Doe', 'Jean-Baptiste Oudry', 'Baroque')
# ('The Wolf and the Lamb', 'Jean-Baptiste Oudry', 'Baroque')
# ('Two Hunting Dogs with Hares and Game Birds', 'Jean-Baptiste Oudry', 'Baroque')
# ('Water Spaniel Surprising a Swan on its Nest', 'Jean-Baptiste Oudry', 'Baroque')
# ('White Greyhound', 'Jean-Baptiste Oudry', 'Baroque')
# ('Elisabeth Farnese', 'Jean Ranc', 'Baroque')
# ('Fernando VI of Spain', 'Jean Ranc', 'Baroque')
# ('Mariana Victoria of Spain', 'Jean Ranc', 'Baroque')
# ('Philip of Spain Duke of Parma', 'Jean Ranc', 'Baroque')
# ('Portrait of a Lady as Pomona', 'Jean Ranc', 'Baroque')
# ('Portrait of Barbara of Portugal', 'Jean Ranc', 'Baroque')
# ('Portrait of Carlos III', 'Jean Ranc', 'Baroque')
# ('Portrait of Fernando VI', 'Jean Ranc', 'Baroque')
# ("Portrait of Louis Elisabeth d'Orleans Queen of Spain", 'Jean Ranc', 'Baroque')
# ('Portrait of Louis I of Spain', 'Jean Ranc', 'Baroque')
# ('Portrait of Philip V of Spain', 'Jean Ranc', 'Baroque')
# ('Vertumno e Pomona', 'Jean Ranc', 'Baroque')
# ('A Boy and a Girl with a Cat and an Eel', 'Judith Leyster', 'Baroque')
# ('A Card Player', 'Judith Leyster', 'Baroque')
# ('Boy Peering into an Earthenware Tankard', 'Judith Leyster', 'Baroque')
# ('Boy Playing the Flute', 'Judith Leyster', 'Baroque')
# ('Cello Player', 'Judith Leyster', 'Baroque')
# ('Jolly Topper', 'Judith Leyster', 'Baroque')
# ('Laughing Children with Cat', 'Judith Leyster', 'Baroque')
# ('Man Offering Money to a Young Woman', 'Judith Leyster', 'Baroque')
# ('Merry Trio', 'Judith Leyster', 'Baroque')
# ('Portrait of a Boy with a Cat, a Red Hat and a Piece of Bread', 'Judith Leyster', 'Baroque')
# ('Serenade', 'Judith Leyster', 'Baroque')
# ('The Last Drop, The Gay Cavalier', 'Judith Leyster', 'Baroque')
# ('A Woman and a Boy with Animals at a Ford', 'Karel Dujardin', 'Baroque')
# ('A Woman with Cattle and Sheep in an Italian Landscape', 'Karel Dujardin', 'Baroque')
# ('Boy Blowing Soap Bubbles', 'Karel Dujardin', 'Baroque')
# ('Drinking Trumpeter on Horseback', 'Karel Dujardin', 'Baroque')
# ('Farm Animals with a Boy and Herdswoman', 'Karel Dujardin', 'Baroque')
# ('Italian Landscape with Goat Star', 'Karel Dujardin', 'Baroque')
# ('Italian Landscape with Soldiers', 'Karel Dujardin', 'Baroque')
# ('Landscape with Mule Driver', 'Karel Dujardin', 'Baroque')
# ('Landscape with Two Donkeys Goats and Pigs', 'Karel Dujardin', 'Baroque')
# ('Muleteers at an Inn', 'Karel Dujardin', 'Baroque')
# ('Sheep and Goats', 'Karel Dujardin', 'Baroque')
# ('St. Paul Healing the Cripple at Lystra', 'Karel Dujardin', 'Baroque')
# ('The Conversion of Saint Paul', 'Karel Dujardin', 'Baroque')
# ('Diana and Her Nymphs in a Landscape', 'Laurent de La Hyre', 'Baroque')
# ('A Peasant Playing a Hurdy-Gurdy to a Woman and Child', 'Nicolaes Berchem', 'Baroque')
# ('A Stag Hunt in a Forest', 'Nicolaes Berchem', 'Baroque')
# ('Landscape with a Nymph and a Satyr', 'Nicolaes Berchem', 'Baroque')
# ('Landscape with Two Horses', 'Nicolaes Berchem', 'Baroque')
# ('Mountainous Landscape with Muleteers', 'Nicolaes Berchem', 'Baroque')
# ('Peasants by a Ruined Aqueduct', 'Nicolaes Berchem', 'Baroque')
# ('The Return from the Hunt', 'Nicolaes Berchem', 'Baroque')
# ('A Bacchanalian Revel Before a Term', 'Nicolas Poussin', 'Baroque')
# ('Blind Orion Searching for the Rising Sun', 'Nicolas Poussin', 'Baroque')
# ('Cephalus and Aurora', 'Nicolas Poussin', 'Baroque')
# ('Confirmation', 'Nicolas Poussin', 'Baroque')
# ('Eucharist', 'Nicolas Poussin', 'Baroque')
# ('Extreme Unction', 'Nicolas Poussin', 'Baroque')
# ('Landscape with a Calm', 'Nicolas Poussin', 'Baroque')
# ('Landscape with a Man Killed by a Snake', 'Nicolas Poussin', 'Baroque')
# ('Landscape with a Man Scooping Water from a Stream', 'Nicolas Poussin', 'Baroque')
# ('Landscape with a Man Washing His Feet at a Fountain', 'Nicolas Poussin', 'Baroque')
# ('Landscape with Travellers Resting', 'Nicolas Poussin', 'Baroque')
# ('Marriage', 'Nicolas Poussin', 'Baroque')
# ('Nymph with Satyrs', 'Nicolas Poussin', 'Baroque')
# ('Ordination', 'Nicolas Poussin', 'Baroque')
# ('Saint John Baptizing in the River Jordan', 'Nicolas Poussin', 'Baroque')
# ('The Adoration of the Golden Calf', 'Nicolas Poussin', 'Baroque')
# ('The Birth of Venus', 'Nicolas Poussin', 'Baroque')
# ('The Companions of Rinaldo', 'Nicolas Poussin', 'Baroque')
# ('The Finding of Moses', 'Nicolas Poussin', 'Baroque')
# ('The Nurture of Bacchus', 'Nicolas Poussin', 'Baroque')
# ('The Rest on the Flight Into Egypt', 'Nicolas Poussin', 'Baroque')
# ('The Triumph of Pan', 'Nicolas Poussin', 'Baroque')
# ('The Victory of Joshua Over the Amalekites', 'Nicolas Poussin', 'Baroque')
# ('Danae¨ and the Shower of Gold', 'Orazio Gentileschi', 'Baroque')
# ('David Contemplating the Head of Goliath', 'Orazio Gentileschi', 'Baroque')
# ('Judith and Her Maidservant with the Head of Holofernes', 'Orazio Gentileschi', 'Baroque')
# ('Moses Saved from the Waters', 'Orazio Gentileschi', 'Baroque')
# ('Portrait of a Young Woman as a Sibyl', 'Orazio Gentileschi', 'Baroque')
# ('Saint Cecilia and an Angel', 'Orazio Gentileschi', 'Baroque')
# ('The Lute Player', 'Orazio Gentileschi', 'Baroque')
# ('A Landscape with Cattle', 'Paulus Potter', 'Baroque')
# ('A Landscape with Cows, Sheep and Horses by a Barn', 'Paulus Potter', 'Baroque')
# ('Animals Resting in the Pasture', 'Paulus Potter', 'Baroque')
# ('Cat Playing with Two Dogs', 'Paulus Potter', 'Baroque')
# ('Cattle and Sheep in a Stormy Landscape', 'Paulus Potter', 'Baroque')
# ('Cattle in a Meadow', 'Paulus Potter', 'Baroque')
# ('Cows Reflected in the Water', 'Paulus Potter', 'Baroque')
# ('Four Cows in the Meadow', 'Paulus Potter', 'Baroque')
# ('Horse', 'Paulus Potter', 'Baroque')
# ('The Bull', 'Paulus Potter', 'Baroque')
# ('The "Piebald" Horse', 'Paulus Potter', 'Baroque')
# ('Two Horses Near a Gate in the Meadow', 'Paulus Potter', 'Baroque')
# ('Two Pigs in a Sty', 'Paulus Potter', 'Baroque')
# ('A Roman Triumph', 'Peter Paul Rubens', '\\N')
# ('A Shepherd with His Flock in a Woody Landscape', 'Peter Paul Rubens', 'Baroque')
# ('Agrippina and Germanicus', 'Peter Paul Rubens', 'Baroque')
# ('Atalanta and Meleager', 'Peter Paul Rubens', 'Baroque')
# ('Aurora Abducting Cephalus', 'Peter Paul Rubens', 'Baroque')
# ('Ceres with Two Nymphs', 'Peter Paul Rubens', 'Baroque')
# ('Cimon and Pero', 'Peter Paul Rubens', 'Baroque')
# ('Cupid Making His Bow', 'Peter Paul Rubens', 'Baroque')
# ('David Meeting Abigail', 'Peter Paul Rubens', 'Baroque')
# ('Decius Mus Addressing the Legions', 'Peter Paul Rubens', 'Baroque')
# ('Diana and Her Nymphs on the Hunt', 'Peter Paul Rubens', 'Baroque')
# ('Diana Cazadora', 'Peter Paul Rubens', 'Baroque')
# ('Erichthonius Discovered by the Daughters of Cecrops', 'Peter Paul Rubens', 'Baroque')
# ('Fortuna', 'Peter Paul Rubens', 'Baroque')
# ('Frans Francken I', 'Peter Paul Rubens', 'Baroque')
# ('Minerva Protects Pax from Mars (Peace and War)', 'Peter Paul Rubens', 'Baroque')
# ('Modello for the Israelites Gathering Manna in the Desert', 'Peter Paul Rubens', 'Baroque')
# ('Pan Syrinx', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of a Man, Possibly an Architect or Geographer', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of a Young Girl (Clara Serena Rubens)', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of Isabella Brant', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of Lady in Waiting to the Infanta Isabella', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of Ludovicus Nonnius', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of the Archduke Albert', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of the Infanta Isabella', 'Peter Paul Rubens', 'Baroque')
# ('Portrait of Thomas Howard, 2nd Earl of Arundel', 'Peter Paul Rubens', 'Baroque')
# ('Saint Teresa of Avila Interceding for Souls in Purgatory', 'Peter Paul Rubens', 'Baroque')
# ('St. Paul', 'Peter Paul Rubens', 'Baroque')
# ('Study of Two Heads', 'Peter Paul Rubens', 'Baroque')
# ('Susanna Fourment', 'Peter Paul Rubens', 'Baroque')
# ('The Birth of the Milky Way', 'Peter Paul Rubens', 'Baroque')
# ('The Brazen Serpent', 'Peter Paul Rubens', 'Baroque')
# ('The Calydonian Boar Hunt', 'Peter Paul Rubens', 'Baroque')
# ('The Christ Child, Saint John and the Lamb', 'Peter Paul Rubens', 'Baroque')
# ('The Crowning of Roxana', 'Peter Paul Rubens', 'Baroque')
# ('The Death of Decius Mus', 'Peter Paul Rubens', 'Baroque')
# ('The Death of Dido', 'Peter Paul Rubens', 'Baroque')
# ('The Fall of Phaeton', 'Peter Paul Rubens', 'Baroque')
# ('The Feast of Achelous', 'Peter Paul Rubens', 'Baroque')
# ('The Holy Family with Saint John the Baptist and an Angel', 'Peter Paul Rubens', 'Baroque')
# ('The Holy Family with Saints Francis and Anne and the Infant Saint John the Baptist', 'Peter Paul Rubens', 'Baroque')
# ('The Holy Family with Saints in a Landscape', 'Peter Paul Rubens', 'Baroque')
# ('The Holy Family with St. Elizabeth, St. John, and a Dove', 'Peter Paul Rubens', 'Baroque')
# ('The Incarnation as Fulfillment of All the Prophecies', 'Peter Paul Rubens', '\\N')
# ('The Judgement of Paris', 'Peter Paul Rubens', 'Baroque')
# ('The Miracles of Saint Francis of Paola', 'Peter Paul Rubens', '\\N')
# ('The Rape of the Sabine Women', 'Peter Paul Rubens', 'Baroque')
# ('The Return from War, Mars Disarmed by Venus', 'Peter Paul Rubens', '\\N')
# ('The Triumphant Entry of Constantine Into Rome', 'Peter Paul Rubens', 'Baroque')
# ('The Union of Earth and Water', 'Peter Paul Rubens', 'Baroque')
# ('Two Satyrs', 'Peter Paul Rubens', 'Baroque')
# ('Venus and Cupid Warming Themselves', 'Peter Paul Rubens', 'Baroque')
# ('Venus and Mars', 'Peter Paul Rubens', 'Baroque')
# ('Wolf and Fox Hunt', 'Peter Paul Rubens', 'Baroque')
# ('Antoine Singlin', 'Philippe De Champaigne', 'Baroque')
# ('Cardinal de Richelieu', 'Philippe De Champaigne', 'Baroque')
# ('Portrait of King Charles II of England', 'Philippe De Champaigne', 'Baroque')
# ('Saint Augustine', 'Philippe De Champaigne', 'Baroque')
# ('The Dream of Saint Joseph', 'Philippe De Champaigne', 'Baroque')
# ('Triple Portrait of the Head of Richelieu', 'Philippe De Champaigne', 'Baroque')
# ('A Still Life with a Roemer, a Crab and a Peeled Lemon', 'Pieter Claesz', 'Baroque')
# ('A Vanitas Still Life', 'Pieter Claesz', 'Baroque')
# ('Still Life with a Red Lobster', 'Pieter Claesz', 'Baroque')
# ('Still Life with a Skull and a Writing Quill', 'Pieter Claesz', 'Baroque')
# ('Still Life with a Turkey Pie', 'Pieter Claesz', 'Baroque')
# ('Still Life with Drinking Vessels', 'Pieter Claesz', 'Baroque')
# ('Still Life with Fruit and Roemer', 'Pieter Claesz', 'Baroque')
# ('Still Life with Herring, Wine and Bread', 'Pieter Claesz', 'Baroque')
# ('Still Life with Salt Tub', 'Pieter Claesz', 'Baroque')
# ('Still Life with Wine Glass and Silver Bowl', 'Pieter Claesz', 'Baroque')
# ('A Couple Playing Cards, with a Serving Woman', 'Pieter De Hooch', 'Baroque')
# ('A Man with Dead Birds, and Other Figures, in a Stable', 'Pieter De Hooch', 'Baroque')
# ('A Mother Delousing Her Child’s Hair', 'Pieter De Hooch', 'Baroque')
# ('A Musical Party in a Courtyard', 'Pieter De Hooch', 'Baroque')
# ('A Woman and Her Maid in a Courtyard', 'Pieter De Hooch', 'Baroque')
# ('A Woman and Two Men in an Arbor', 'Pieter De Hooch', 'Baroque')
# ('A Woman Drinking with Two Men', 'Pieter De Hooch', 'Baroque')
# ('A Woman Preparing Bread and Butter for a Boy', 'Pieter De Hooch', 'Baroque')
# ('Figures in a Courtyard Behind a House', 'Pieter De Hooch', 'Baroque')
# ('Interior with a Young Couple', 'Pieter De Hooch', 'Baroque')
# ('Interior with Women Beside a Linen Cupboard', 'Pieter De Hooch', 'Baroque')
# ('Leisure Time in an Elegant Setting', 'Pieter De Hooch', 'Baroque')
# ('Man Handing a Letter to a Woman in the Entrance Hall of a House', 'Pieter De Hooch', 'Baroque')
# ('Party', 'Pieter De Hooch', 'Baroque')
# ('Paying the Hostess', 'Pieter De Hooch', 'Baroque')
# ('Portrait of a Family Playing Music', 'Pieter De Hooch', 'Baroque')
# ('The Courtyard of a House in Delft', 'Pieter De Hooch', 'Baroque')
# ('The Visit', 'Pieter De Hooch', 'Baroque')
# ('Two Soldiers and a Woman Drinking', 'Pieter De Hooch', 'Baroque')
# ('Woman with a Child in a Pantry', 'Pieter De Hooch', 'Baroque')
# ('Woman with a Water Pitcher, and a Man by a Bed (The Maidservant)', 'Pieter De Hooch', 'Baroque')
# ('Interior of the Sint-Odulphuskerk in Assendelft', 'Pieter Jansz. Saenredam', 'Baroque')
# ('Interior of the Church of St. Bavo in Haarlem', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Interior of Saint Bavo, Haarlem', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Interior of the Buurkerk at Utrecht', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Interior of the Grote Kerk at Haarlem', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Nave and Choir of the Mariakerk in Utrecht', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Old Town Hall of Amsterdam', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Transept of the Mariakerk in Utrecht, seen from the Northeast', 'Pieter Jansz. Saenredam', 'Baroque')
# ('The Westernmost Bays of the South Aisle of the Mariakerk in Utrech', 'Pieter Jansz. Saenredam', 'Baroque')
# ('A Man and a Woman in a Stableyard', 'Pieter Quast', 'Baroque')
# ('A Standing Man', 'Pieter Quast', 'Baroque')
# ('Still Life with Flowers in a Glass Vase', 'Rachel Ruysch', 'Baroque')
# ('Still Life with Flowers on a Marble Tabletop', 'Rachel Ruysch', 'Baroque')
# ('A Bearded Man in a Cap', 'Rembrandt Van Rijn', 'Baroque')
# ('A Bearded Man Wearing a Hat', 'Rembrandt Van Rijn', 'Baroque')
# ('A Franciscan Friar', 'Rembrandt Van Rijn', 'Baroque')
# ('A Lady and Gentleman in Black', 'Rembrandt Van Rijn', 'Baroque')
# ('A Man Seated Reading at a Table in a Lofty Room', 'Rembrandt Van Rijn', 'Baroque')
# ('A Polish Nobleman', 'Rembrandt Van Rijn', 'Baroque')
# ('A Scholar in His Study', 'Rembrandt Van Rijn', 'Baroque')
# ('A Scholar Seated at a Desk', 'Rembrandt Van Rijn', 'Baroque')
# ('A Seated Man with a Stick', 'Rembrandt Van Rijn', 'Baroque')
# ('A Study of an Elderly Man in a Cap', 'Rembrandt Van Rijn', 'Baroque')
# ('A Young Man and a Girl Playing Cards', 'Rembrandt Van Rijn', 'Baroque')
# ('A Young Scholar and His Tutor', 'Rembrandt Van Rijn', 'Baroque')
# ('An Elderly Man as Saint Paul', 'Rembrandt Van Rijn', 'Baroque')
# ('An Old Man in an Armchair', 'Rembrandt Van Rijn', 'Baroque')
# ('An Old Man in Military Costume', 'Rembrandt Van Rijn', 'Baroque')
# ('An Old Man in Red', 'Rembrandt Van Rijn', 'Baroque')
# ('Aristotle with a Bust of Homer', 'Rembrandt Van Rijn', 'Baroque')
# ('Balaam and His Ass', 'Rembrandt Van Rijn', 'Baroque')
# ('Bathsheba at Her Bath', 'Rembrandt Van Rijn', 'Baroque')
# ('Bellona', 'Rembrandt Van Rijn', 'Baroque')
# ("Belshazzar's Feast", 'Rembrandt Van Rijn', 'Baroque')
# ('Bust of a Man in a Gorget and a Feathered Beret', 'Rembrandt Van Rijn', 'Baroque')
# ('Christ and the Woman of Samaria', 'Rembrandt Van Rijn', 'Baroque')
# ('Christ with a Staff', 'Rembrandt Van Rijn', 'Baroque')
# ('Daniel and Cyrus Before the Idol Bel', 'Rembrandt Van Rijn', 'Baroque')
# ('Descent from the Cross', 'Rembrandt Van Rijn', 'Baroque')
# ('Diana Bathing with Her Nymphs', 'Rembrandt Van Rijn', 'Baroque')
# ('Head of a Boy', 'Rembrandt Van Rijn', 'Baroque')
# ('Head of Christ', 'Rembrandt Van Rijn', 'Baroque')
# ('Hendrickje Bathing in a River', 'Rembrandt Van Rijn', 'Baroque')
# ('Hendrickje Stoffels', 'Rembrandt Van Rijn', 'Baroque')
# ('Herman Doomer', 'Rembrandt Van Rijn', 'Baroque')
# ('Jacob Blessing', 'Rembrandt Van Rijn', 'Baroque')
# ('Jeremiah Lamenting the Destruction of Jerusalem', 'Rembrandt Van Rijn', 'Baroque')
# ('Johannes Wtenbogaert', 'Rembrandt Van Rijn', 'Baroque')
# ('Large Self-Portrait', 'Rembrandt Van Rijn', 'Baroque')
# ('Laughing Young Man', 'Rembrandt Van Rijn', 'Baroque')
# ('Lieven Willemsz Van Coppenol', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in a Beret', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in a Fur-lined Coat', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in a Red Cloak', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in Armor (Mars)', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in Oriental Clothing', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in Oriental Costume', 'Rembrandt Van Rijn', 'Baroque')
# ('Man in Oriental Dress', 'Rembrandt Van Rijn', 'Baroque')
# ('Man with a Beard', 'Rembrandt Van Rijn', 'Baroque')
# ('Man with a Magnifying Glass', 'Rembrandt Van Rijn', 'Baroque')
# ('Man with a Steel Gorget', 'Rembrandt Van Rijn', 'Baroque')
# ('Minerva', 'Rembrandt Van Rijn', 'Baroque')
# ('Old Man with a Gold Chain', 'Rembrandt Van Rijn', 'Baroque')
# ('Old Woman Cutting Her Nails', 'Rembrandt Van Rijn', 'Baroque')
# ('Pilate Washing His Hands', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Lady with an Ostrich-Feather Fan', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Man, Member of the Van Beresteyn Family', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Man, Seated', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Man (The Auctioneer)', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Man with a Breastplate and Plumed Hat', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Woman, the Van Beresteyn Family', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of a Young Woman with a Fan', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Dirck Jansz. Pesser', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Hendrickje Stoffels', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Jacob de Gheyn (III)', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Jacob Trip', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Maertgen van Bilderbeecq', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Margaretha de Geer, Wife of Jacob Trip', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Marten Looten', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Nicolaes Ruts', 'Rembrandt Van Rijn', 'Baroque')
# ('Portrait of Rembrandt Van Rijn', 'Rembrandt Van Rijn', 'Baroque')
# ('Rembrandt as a Young Man', 'Rembrandt Van Rijn', 'Baroque')
# ("Rembrandt's Son Titus", 'Rembrandt Van Rijn', 'Baroque')
# ('Saskia Van Uylenburgh in Arcadian Costume', 'Rembrandt Van Rijn', 'Baroque')
# ('Saskia Van Uylenburgh, the Wife of the Artist', 'Rembrandt Van Rijn', 'Baroque')
# ('Saskia', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait as the Apostle St. Paul', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait at 34', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait at an Early Age', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait in a Gorget', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait in a Velvet Beret', 'Rembrandt Van Rijn', 'Baroque')
# ('Self-Portrait with Two Circles', 'Rembrandt Van Rijn', 'Baroque')
# ('Sophonisba Receives the Cup of Poison', 'Rembrandt Van Rijn', 'Baroque')
# ('St. Bartholomew', 'Rembrandt Van Rijn', 'Baroque')
# ('St. Peter in Prison (The Apostle Peter Kneeling)', 'Rembrandt Van Rijn', 'Baroque')
# ("St. Peter's Denial", 'Rembrandt Van Rijn', 'Baroque')
# ('The Abduction of Europa', 'Rembrandt Van Rijn', 'Baroque')
# ('The Anatomy Lesson of Dr. Jan Deyman', 'Rembrandt Van Rijn', 'Baroque')
# ('The Beheading of John the Baptist', 'Rembrandt Van Rijn', 'Baroque')
# ('The Conspiracy of the Batavians Under Claudius Civilis', 'Rembrandt Van Rijn', 'Baroque')
# ('The Jewish Bride', 'Rembrandt Van Rijn', 'Baroque')
# ('The Mennonite Preacher Anslo and His Wife', 'Rembrandt Van Rijn', 'Baroque')
# ('The Music Party', 'Rembrandt Van Rijn', 'Baroque')
# ('The Night Watch', 'Rembrandt Van Rijn', 'Baroque')
# ('The Philosopher', 'Rembrandt Van Rijn', 'Baroque')
# ('The Polish Rider', 'Rembrandt Van Rijn', 'Baroque')
# ("The Prophetess Anna, Rembrandt's Mother", 'Rembrandt Van Rijn', 'Baroque')
# ('The Raising of Lazarus', 'Rembrandt Van Rijn', 'Baroque')
# ('The Shipbuilder and His Wife', 'Rembrandt Van Rijn', 'Baroque')
# ('The Slaughtered Ox', 'Rembrandt Van Rijn', 'Baroque')
# ('The Standard Bearer (Floris Soop)', 'Rembrandt Van Rijn', 'Baroque')
# ('The Stone Bridge', 'Rembrandt Van Rijn', 'Baroque')
# ('The Toilet of Bathsheba', 'Rembrandt Van Rijn', 'Baroque')
# ("Titus Van Rijn in a Monk's Habit", 'Rembrandt Van Rijn', 'Baroque')
# ('Tobit and Anna with the Kid Goat', 'Rembrandt Van Rijn', 'Baroque')
# ('Tronie of a Man with a Feathered Beret', 'Rembrandt Van Rijn', 'Baroque')
# ('Woman with a Pink', 'Rembrandt Van Rijn', 'Baroque')
# ('Young Woman with a Red Necklace', 'Rembrandt Van Rijn', 'Baroque')
# ('Aeneas and His Father Fleeing Troy', 'Simon Vouet', 'Baroque')
# ('Allegorical Portrait of Anna of Austria as Minerva', 'Simon Vouet', 'Baroque')
# ('Boy with a Flute', 'Simon Vouet', 'Baroque')
# ('Ceres and Harvesting Cupids', 'Simon Vouet', 'Baroque')
# ('Judith and the Head of Holofernes', 'Simon Vouet', 'Baroque')
# ('Loth and His Daughters', 'Simon Vouet', 'Baroque')
# ('Louis XIII Between Two Female Figures', 'Simon Vouet', 'Baroque')
# ('Portrait of a Gentleman with His Dog', 'Simon Vouet', 'Baroque')
# ('Saint Peter Visiting Saint Agatha in Prison', 'Simon Vouet', 'Baroque')
# ('St. Catherine', 'Simon Vouet', 'Baroque')
# ('The Muses Urania and Calliope', 'Simon Vouet', 'Baroque')
# ('Venus and Adonis', 'Simon Vouet', 'Baroque')
# ("Virginia da Vezzo, the Artist's Wife, as the Magdalen", 'Simon Vouet', 'Baroque')
# ('Wealth', 'Simon Vouet', 'Baroque')
# ('Andromeda Chained to the Rock', 'Sir Anthony Van Dyck', 'Baroque')
# ('Charles I in Three Positions', 'Sir Anthony Van Dyck', 'Baroque')
# ('Charles I with M. De St. Antoine', 'Sir Anthony Van Dyck', 'Baroque')
# ('Cornelis Van Der Geest', 'Sir Anthony Van Dyck', 'Baroque')
# ('Drunken Silenus Supported by Satyrs', 'Sir Anthony Van Dyck', 'Baroque')
# ('Equestrian Portrait of Charles I', 'Sir Anthony Van Dyck', 'Baroque')
# ('Francois Langlois', 'Sir Anthony Van Dyck', 'Baroque')
# ('James Stuart, Duke of Lennox and Richmond', 'Sir Anthony Van Dyck', 'Baroque')
# ('Katherine, Countess of Chesterfield and Lucy, Countess of Huntingdon', 'Sir Anthony Van Dyck', 'Baroque')
# ('Lady Elizabeth Thimbelby and Her Sister', 'Sir Anthony Van Dyck', 'Baroque')
# ('Lamentation Over Dead Christ', 'Sir Anthony Van Dyck', 'Baroque')
# ('Mary Ruthven', 'Sir Anthony Van Dyck', 'Baroque')
# ('Nicholas Lanier', 'Sir Anthony Van Dyck', 'Baroque')
# ('Philip Herbert, 4th Count of Pembroke', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of a Genoese Noblewoman with Her Son', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of Agostino Pallavicini', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of an Unknown Genoese Lady', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of Charles I', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of the Earl and Countess Arundel', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portrait of the Five Eldest Children of Charles I', 'Sir Anthony Van Dyck', 'Baroque')
# ('Portraits of Two Young Englishmen', 'Sir Anthony Van Dyck', 'Baroque')
# ('Prince Rupert, Count Palatine', 'Sir Anthony Van Dyck', 'Baroque')
# ('Princess Mary, Daughter of Charles I', 'Sir Anthony Van Dyck', 'Baroque')
# ('Saint Francis of Assisi in Ecstasy', 'Sir Anthony Van Dyck', 'Baroque')
# ('Study Head of a Young Woman', 'Sir Anthony Van Dyck', 'Baroque')
# ('Study Head of an Old Man with a White Beard', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Apostle Simon', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Cardinal Infante Fernando de Austria', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Horses of Achilles', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Musician Enrique Liberti', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Penitent Apostle Peter', 'Sir Anthony Van Dyck', 'Baroque')
# ('The Vision of the Blessed Hermann Joseph', 'Sir Anthony Van Dyck', 'Baroque')
# ('Thomas Howard, 2nd Earl of Arundel', 'Sir Anthony Van Dyck', 'Baroque')
# ('Thomas Kiligrew and William Lord Crofts', 'Sir Anthony Van Dyck', 'Baroque')
# ('Virgin and Child with Saint Catherine of Alexandria', 'Sir Anthony Van Dyck', 'Baroque')
# ('Barbara Villiers, Duchess of Cleveland', 'Sir Peter Lely', 'Baroque')
# ('Cornelis Van Tromp', 'Sir Peter Lely', 'Baroque')
# ('Edward Montagu, First Earl of Sandwich', 'Sir Peter Lely', 'Baroque')
# ('Flagmen of Lowestoft Admiral Sir Thomas Allin', 'Sir Peter Lely', 'Baroque')
# ('Flagmen of Lowestoft Edward Montagu, First Earl of Sandwich', 'Sir Peter Lely', 'Baroque')
# ('Flagmen of Lowestoft George Monck, 1st Duke of Albermarle', 'Sir Peter Lely', 'Baroque')
# ('Flagmen of Lowestoft Vice-Admiral Sir Thomas Teddeman', 'Sir Peter Lely', 'Baroque')
# ('Flagmen of Lowestoft Vice-Admiral Sir William Berkeley', 'Sir Peter Lely', 'Baroque')
# ('Portrait of Louise de Keroualle, Duchess of Portsmouth', 'Sir Peter Lely', 'Baroque')
# ('Portrait of Mrs Leneve', 'Sir Peter Lely', 'Baroque')
# ('Prince Rupert, First Duke of Cumberland and Count Palatine of the Rhine', 'Sir Peter Lely', 'Baroque')
# ('Banquet Piece with Ham', 'Willem Claesz. Heda', 'Baroque')
# ('Banquet Piece with Mince Pie', 'Willem Claesz. Heda', 'Baroque')
# ('Breakfast Piece', 'Willem Claesz. Heda', 'Baroque')
# ('Dessert', 'Willem Claesz. Heda', 'Baroque')
# ('Pewter and Silver Vessels and a Crab', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with a Broken Glass', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with a Gilded Beer Tankard', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with a Gilt Cup', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with a Lobster', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with a Nautilus Cup', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with Oysters, a Rummer, a Lemon and a Silver Bowl', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with Roemer and Silver Tazza', 'Willem Claesz. Heda', 'Baroque')
# ('Still Life with Tobacco, Wine and a Pocket Watch', 'Willem Claesz. Heda', 'Baroque')
# ('A Musical Party', 'Willem Duyster', 'Baroque')
# ('Family Group with a Black Man', 'Willem Duyster', 'Baroque')
# ('Soldiers Fighting Over Booty in a Barn', 'Willem Duyster', 'Baroque')
# ('Two Men Playing Tric Trac with a Woman Scoring', 'Willem Duyster', 'Baroque')

# %% [markdown]
# 3 - Find all the museums in the USA and return their total number  [4 marks]
#
# Implement a query that returns all the museums in the USA and calculates the number of museums in that country. Your query should return the names of the museums and only one value for the total number of museums in the USA.

# %%
# your code here
try:
    with connection.cursor() as cur:
        cur.execute(""" 
            SELECT museum_name FROM museums WHERE museum_country = "USA"
        """)
        results = cur.fetchall()
        for row in results:
            print(row)

        cur.execute("""
            SELECT COUNT(*) FROM museums WHERE museum_country = "USA";
        """)
        count = cur.fetchone()[0]
        print(f"Total Museums in the USA:  {count}")
finally:
    pass
# Out:
# ('Los Angeles County Museum of Art',)
# ('The Metropolitan Museum of Art',)
# ('National Gallery of Art',)
# ('The J. Paul Getty Museum',)
# ('Cleveland Museum Of Art',)
# ('Philadelphia Museum of Art',)
# ('The Barnes Foundation',)
# ('The Art Institute of Chicago',)
# ('The Museum of Modern Art',)
# ('Solomon R. Guggenheim Museum',)
# ('Toledo Museum of Art',)
# ('Nelson-Atkins Museum of Art',)
# ('Saint Louis Art Museum',)
# ('Fine Arts Museums of San Francisco Legion of Honor',)
# ('The Phillips Collection',)
# ('Indianapolis Museum of Art',)
# ('Smithsonian American Art Museum',)
# ('Museum of Fine Arts, Houston',)
# ('Museum of Fine Arts Boston',)
# ('Walters Art Museum',)
# ('Columbus Museum of Art',)
# ('Kimbell Art Museum',)
# ('Dallas Museum of Art',)
# ('Chrysler Museum of Art',)
# ('Norton Simon Museum',)
# Total Museums in the USA:  25

# %% [markdown]
# 4 - Find all the Dutch artists who were Portraitist, and their paintings are displayed in a museum in Amsterdam . [4 marks]
#
# Implement a query that retrieves all the artists who have Dutch nationality and Portraitist style with paintings displayed in a museum in Amsterdam city. The returned table should have three columns: artist, painting name and museum.

# %%
# your code here
try:
    with connection.cursor() as cur:
        cur.execute(""" 
            SELECT artists.artist_name, paintings.painting_name, museums.museum_name FROM artists
            JOIN paintings ON artists.artist_id = paintings.artist_id
            JOIN museums ON museums.museum_id = paintings.museum_id  
            WHERE artists.artist_style = "Portraitist" AND artists.artist_nationality = "Dutch" AND museums.museum_city = "Amsterdam";
        """)

        results = cur.fetchall()
        for row in results:
            print(row)
finally:
    pass
# Out:
# ('Adriaan De Lelie', 'Barend Klijn Barendsz, Poet', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Cornelis Sebille Roos, Amsterdam Art Dealer and Keeper of the Nationale Konst-Gallery in Huis ten Bosch, The Hague', 'Rijksmuseum')
# ('Adriaan De Lelie', 'General Daendels Taking Leave of Lieutenant-Colonel Krayenhoff', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Jonkheer Gysbert Carel Rutger Reinier van Brienen van Ramerus, with his Wife and four of their Children', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Morning Visit', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Portrait of Albertus Henricus Wiese, Governor-General of the Dutch East Indies', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Portrait of Gerrit Verdooren, Vice-admiral', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Portrait of Hendrick de Hartog', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Portrait of the Family of Adrianus Bonebakker with Dirk L. Bennewitz', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Portrait of Wilhelmina Maria Haack, fourth Wife of Gerrit Verdooren', 'Rijksmuseum')
# ('Adriaan De Lelie', 'The Art Gallery of Jan Gildemeester Jansz', 'Rijksmuseum')
# ('Adriaan De Lelie', 'The Art Gallery of Josephus Augustinus Brentano', 'Rijksmuseum')
# ('Adriaan De Lelie', 'The Drawing Gallery of the Felix Meritis Society', 'Rijksmuseum')
# ('Adriaan De Lelie', 'The Sculpture Gallery of the Felix Meritis Society', 'Rijksmuseum')
# ('Adriaan De Lelie', 'Woman Baking Pancakes', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Aert van Nes, Vice Admiral', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Banquet at the Crossbowmen’s Guild in Celebration of the Treaty of Mu¨nster', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Egbert Meeuwsz Cortenaer, Vice Admiral, Admiralty of the Maas, Rotterdam', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Geertruida den Dubbelde, Wife of Aert van Nes', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Jacobus Trip, Armaments Dealer of Amsterdam and Dordrecht', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Johan de Liefde, Vice-Admiral', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Maria Pietersdr de Leest, Wife of Samuel van Lansbergen', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Mary Stuart, Princess of Orange, as Widow of William II', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Militia Company of District VIII under the Command of Captain Roelof Bicker', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Portrait of a Young Man in Military Costume', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Portrait of Andries Bicker', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Portrait of Gerard Andriesz Bicker', 'Rijksmuseum')
# ('Bartholomeus Van Der Helst', 'Samuel van Lansbergen, Remonstrant Minister in Rotterdam', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Catharina Annette Fraser', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Dieuwke Fontein, Second Wife of Adriaan van der Hoop', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Dr. Cornelis Hendrik a Roy, Physician and Biographer', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Gijsbertus Johannes Rooyens, Professor of Theology and Church History at the University of Amsterdam', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Girl Resting', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Portrait of Alida Christina Assink', 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Portrait of William II, King of the Netherlands', 'Rijksmuseum')
# ('Jan Adam Kruseman', "Regents and Regentesses of the Lepers' Asylum, Amsterdam", 'Rijksmuseum')
# ('Jan Adam Kruseman', 'Rodolphe le Chevalier, Amsterdam Merchant and one of Three Founders of the Holland Railroad Company', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Agatha Petronella Hartsen', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Allegory of the Death of William V, Prince of Orange', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Arcadian Landscape', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Hendrik Harmen Klijn', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Louis Royer, Sculptor, and Albertus Bernardus Roothaan, Stockbroker, Friend of the Arts, and Patron of the Sciences', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Pieter Merkus, Governor General', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait of a Woman and a Man', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait of Baron David Hendrik Chasse, Lieutenant-General', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait of Jacob Hobein, Rescued the Dutch Flag under Enemy Fire, 18 March 1831', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait of Jonkheer Jan Willem Janssens, Governor of the Cape Colony and Governor-General of the Dutch East Indies', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait of Sara de Haan, Widow of the Amsterdam Underwriter Cornelis Hartsen', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Portrait Study of Arthur Wellesley, Duke of Wellington', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'The Battle of Waterloo', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'The Voluntary Sacrifice of Reverend Hambroeck on Taiwan', 'Rijksmuseum')
# ('Jan Willem Pieneman', 'Triumvirate Assuming Power in the Name of the Prince of Orange, 21 November 1813', 'Rijksmuseum')
# ('Willem Bartel Van Der Kooi', 'Jan Baptist Kobell II, Painter', 'Rijksmuseum')
# ('Willem Bartel Van Der Kooi', 'Piano Practice Interrupted', 'Rijksmuseum')
# ('Willem Bartel Van Der Kooi', "Self-Portrait, Pointing at a Portrait of the Artist's Colleague Dirk Jacobsz Ploegsma", 'Rijksmuseum')

# %% [markdown]
# 5 - Find all the French Expressionist painters who painted flowers and count how many of those paintings are displayed in New York, USA  [4 marks]
#
# Implement a query that retrieves all the painter with French nationality with Expressionist style whose painting subjects were flowers. Your returned table should contain 4 columns: painting, artist, museum, museum_city. Then calculate how many of those flower paintings by French Expressionists are displayed in New York museums. This query should return only one value.

# %%
# your code here
# your code here
try:
    with connection.cursor() as cur:
        cur.execute(""" 
            WITH valid_paintings AS (
                SELECT paintings.painting_name, artists.artist_name, museums.museum_name, museums.museum_city FROM paintings
                JOIN artists ON artists.artist_id = paintings.artist_id
                JOIN museums ON museums.museum_id = paintings.museum_id  
                WHERE artists.artist_style = 'Expressionist' AND artists.artist_nationality = 'French' AND paintings.painting_subject = 'flowers'
            
            )
            
            SELECT painting_name, artist_name, museum_name, museum_city FROM valid_paintings
                    
        """)
        results = cur.fetchall()
        for row in results:
            print(row)
        
        cur.execute("""
            SELECT COUNT(*)
            FROM paintings
            JOIN artists ON artists.artist_id = paintings.artist_id
            JOIN museums ON museums.museum_id = paintings.museum_id
            WHERE artists.artist_style = 'Expressionist' AND artists.artist_nationality = 'French' AND paintings.painting_subject = 'flowers'
                AND museum_city = 'New York';
        """)
        count = cur.fetchone()[0]
        print(f"Total French Expressionist painters that painted Flowers in New York: {count}")
finally:
    pass
# Out:
# ('Bouquet of Roses', 'Albert André', '\\N', '\\N')
# ('Dahlias', 'Albert André', '\\N', '\\N')
# ('Flower Vase and Fruits', 'Albert André', '\\N', '\\N')
# ('Roses in a Glass', 'Albert André', '\\N', '\\N')
# ('Still Life', 'Albert André', '\\N', '\\N')
# ('The Bouquet (View from the Artist’s Studio, Paris)', 'Albert André', '\\N', '\\N')
# ('Vase of Flower by the Window', 'Albert André', '\\N', '\\N')
# ('Vase of Flowers and Fruits on the Table', 'Albert André', '\\N', '\\N')
# ('White Vase with Flowers', 'Albert André', '\\N', '\\N')
# ('Bouquet of Roses and Fruit', 'Albert André', 'The Metropolitan Museum of Art', 'New York')
# ('Bouquet of Flowers', 'Chaïm Soutine', 'The Barnes Foundation', 'Philadelphia')
# Total French Expressionist painters that painted Flowers in New York: 1
